# %% [markdown]
# **If you lost points on the last checkpoint you can get them back by responding to TA/IA feedback**
#
# Update/change the relevant sections where you lost those points, make sure you respond on GitHub Issues to your TA/IA to call their attention to the changes you made here.
#
# Please update your Timeline... no battle plan survives contact with the enemy, so make sure we understand how your plans have changed.
#
# To Do:
# - switch to one dataset (exclude Jun, jul, aug, sep, and include no snowfall values)
# - revise research question and hypothesis (mention the exclusion of months in the dataset, and no need to include prediction model we will use)
# - give justification on why we're excluding these months (analyze months with the most no snowfall)
# - change EDA based on the new cleaned dataset
# - update data overview(description) and code based on new dataset
# - remove date from the summary of data (Descriptive Statistics)
# - update timeline
# - include trace (replace with 0? or another value?), trace is less than 0.254cm (explain this change in data overview and discuss potential bias based on this change, could argue that 0.254 is relatively close to 0, a difference of 0.254 might be insignificant and doesn't affect the data/model significantly or not?)

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Nomin Batjargal
# - Marisol Jaramillo
# - Vincent Ly
# - Cooper Ward
# - Jonathan Fuller

# %% [markdown]
# # Research Question

# %% [markdown]
# Using historical daily data on relative humidity, maximum and minimum temperatures, can we estimate the amount of total snowfall (in centimeters) that will occur on a given day via multiple linear regression model that uses relative humidity, maximum temperature, and minimum temprature to predict total snowfall?

# %% [markdown]
# # Research Question Revision

# %% [markdown]
# Using historical daily data on maximum and minimum temperatures, along with relative humidity data, from October through May, can we accurately estimate the amount of total snowfall (in centimeters) that will occur on a given day at using a machine learning model? The analysis excludes summer months (June through September) due to their historically negligible snowfall patterns.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# As a Mediterranean climate, California’s annual precipitation is largely restricted to a short season from November through March and is characterized by highly variable annual precipitation. The extreme variability in precipitation can be partially attributed to the presence or absence of atmospheric rivers which are bands of water vapor that form over the tropics and are responsible for as much as 50% of California’s annual precipitation[<sup>1</sup>](#1). As climate change progresses, it is projected that California will experience an even greater whiplash between years of extreme wetness and years of extreme dryness[<sup>2</sup>](#2). Although precipitation in general is important to consider, it is actually snowfall that is most important in terms of California’s water supply because it serves as a natural form of water storage and supplies approximately a third of California’s water[<sup>3</sup>](#3). The amount of snowfall that California receives has a huge impact on agriculture, tourism, hydroelectric power generation, and of course our water supply. As of now, it is difficult to accurately predict how much snowfall will occur on a given day. Increasing the accuracy with which snowfall predictions can be made would be a boon for water management which could mitigate some of the destructive impacts of increasingly severe droughts. Weather factors that could aid in snowfall forecasting are humidity which has been shown to have a positive relationship with snowfall and temperature which has been shown to have a negative relationship with snowfall, as these two factors are said to be the most vital variables when predicting snowfall[<sup>4</sup>](#4). With these relationships in mind, we wonder if historical data on a day’s relative humidity, maximum air temperature, minimum air temperature, and the resulting amount of snowfall in centimeters could be used to create a model that more accurately predicts the amount of snowfall that will occur.
#
# Similar work has previously been conducted in which historical data has been used to try to predict future snowfall. For instance, an analysis was conducted using historical data on annual snowfall and maximum annual snowfall to develop a multiple linear regression model to estimate future snowfall for years 2020 to 2060 in Denver Colorado[<sup>5</sup>](#5). Unsurprisingly, the model predicted that annual snowfall would drastically decline in Denver by 2060. Although a prediction of declining snowfall is consistent with projections of decreases in mean annual snowfall due to climate change, a multiple linear regression model is a somewhat simplistic way to model a phenomenon as variable and non-linear as weather. Furthermore, it is important to understand how much snowfall will occur annually, but it may be even more important to know how much snowfall will occur on a given day. Officials who manage reservoirs in California often have to release water in anticipation of upcoming storms, but have to balance letting enough water out to not cause flooding and letting too much out that it endangers future water supply. An accurate understanding of how much snowfall will occur as a result of a storm would allow officials to better manage the precious water supply. Although a multiple linear regression model is a rather unsophisticated method to predict future snowfall, more sophisticated attempts have also been made to make predictions based on historical data. For example, a long short-term memory recurrent neural network was trained using 20 years of historical winter data that included variables such as maximum temperature, minimum temperature, rainfall, snowfall, and relative humidity to predict snowfall at a weather station[<sup>6</sup>](#6). The paper claims that the model predicted snowfall with a high level of accuracy, but it seems as though the model only predicted the occurrence of snow rather than the amount of snow that fell. It is encouraging to see that a model can predict with accuracy whether  snow will occur based on parameters such as maximum temperature, minimum temperature, rainfall, snowfall, and relative humidity but it remains to be seen if we can develop a model that can predict the precise amount of snow that will fall on a day based on the temperature and relative humidity.
#
# [<sup>1</sup>](#1):Dettinger, Michael D., et al. “Atmospheric rivers, floods and the water resources of California.” Water, vol. 3, no. 2, 24 Mar. 2011, pp. 445–478, [https://doi.org/10.3390/w3020445.](https://doi.org/10.3390/w3020445.)
#
# [<sup>2</sup>](#2):Swain, Daniel L., et al. “Increasing precipitation volatility in twenty-first-century California.” Nature Climate Change, vol. 8, no. 5, 23 Apr. 2018, pp. 427–433, [https://doi.org/10.1038/s41558-018-0140-y.](https://doi.org/10.1038/s41558-018-0140-y.)
#
# [<sup>3</sup>](#3):Bland, Alastair. “California Storms Create Paradox: Too Much Water in Reservoirs, Too Soon.” CalMatters, 10 Mar. 2023, [calmatters.org/environment/2023/03/california-storm-reservoirs-flooding/.](calmatters.org/environment/2023/03/california-storm-reservoirs-flooding/.)
#
# [<sup>4</sup>](#4):Zhang, Xueting, et al. “Environmental factors influencing snowfall and snowfall prediction in the Tianshan Mountains, Northwest China.” Journal of Arid Land, vol. 11, no. 1, 27 Dec. 2018, pp. 15–28, [https://doi.org/10.1007/s40333-018-0110-2.](https://doi.org/10.1007/s40333-018-0110-2.)
#
# [<sup>5</sup>](#5):Palkovic, Martin. “Estimating Future Snowfall in Denver, Colorado Using Machine Learning in Python.” Medium, Towards Data Science, 5 June 2022, [medium.com/towards-data-science/estimating-future-snowfall-in-denver-colorado-using-machine-learning-in-python-ada88a531001.](https://medium.com/towards-data-science/estimating-future-snowfall-in-denver-colorado-using-machine-learning-in-python-ada88a531001)
#
# [<sup>6</sup>](#6):Sehvish Riyaz , Dr. Ashish Oberoi. Snowfall Prediction Using Artificial Recurrent Neural Network (RNN)International Journal of Innovative Research in Computer Science and Technology (IJIRCST), Vol-11, no.1, January, 2023,pp. 5-9, [doi:10.55524/ijircst.2023.11.1.2.](doi:10.55524/ijircst.2023.11.1.2.)

# %% [markdown]
# # Hypothesis

# %% [markdown]
# - We predict that the total amount of snowfall in centimeters for a given day will have a negative relationship with temperature and a positive relationship with relative humidity. We believe that the total amount of snow predicted by the model will be negatively impacted by increasing temperature as higher temperatures have been shown to reduce the likelihood of snowfall. Conversely, estimated snowfall will increase as relative humidity levels increase as higher humidity levels have been shown to promote more intense snowfall. Additionally, using a specifics day's termperature and humidity, we will be able to predict the amount of snowfall on that given day.

# %% [markdown]
# # Hypothesis Revision

# %% [markdown]
# We predict that the total amount of snowfall in centimeters for a given day during the snow season (October through May) will have a negative relationship with both maximum and minimum temperatures, and a positive relationship with relative humidity. We believe that the total amount of snow predicted will be negatively impacted by increasing temperatures, as higher temperatures reduce the likelihood of snowfall. Conversely, we expect estimated snowfall to increase as relative humidity levels increase, as higher humidity levels have been shown to promote more intense snowfall. Additionally, using a specific day's temperatures and humidity data, we aim to use a machine learning model to predict the amount of snowfall on that given day.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
# - Dataset #2 (if you have more than one!)
#   - Dataset Name:
#   - Link to the dataset:
#   - Number of observations:
#   - Number of variables:
# - etc
#
# Now write 2 - 5 sentences describing each dataset here. Include a short description of the important variables in the dataset; what the metrics and datatypes are, what concepts they may be proxies for. Include information about how you would need to wrangle/clean/preprocess the dataset
#
# If you plan to use multiple datasets, add a few sentences about how you plan to combine these datasets.

# %% [markdown]
# ## Sierra Nevada Mountains Dataset

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
import pandas as pd
import numpy as np

def print_data_summary(df,wanted_columns):
    print("\nDataset Summary:")
    print(f"Shape: {df.shape}")
    print("\nMissing Values:")
    print(df.isna().sum())
    print("\nData Types:")
    print(df.dtypes)
    print("\nDescriptive Statistics:")
    return df[wanted_columns].describe()

# read in data 
cssl_data = pd.read_csv('donner_pass.csv')

# select relevant columns
selected_columns = ['Date', 'Air Temp Max (C)', 'Air Temp Min (C)', 'New Snow (cm)']
cssl_data = cssl_data[selected_columns]


#take a look at dataframe 
cssl_data
# Out:
#              Date Air Temp Max (C) Air Temp Min (C) New Snow (cm)
# 0      1970-10-01             22.2            4.995             0
# 1      1970-10-02            24.42            4.995             0
# 2      1970-10-03            23.31             5.55             0
# 3      1970-10-04           22.755             3.33             0
# 4      1970-10-05           17.205             3.33             0
# ...           ...              ...              ...           ...
# 17892  2019-09-26               23                8             0
# 17893  2019-09-27               18                7             0
# 17894  2019-09-28                8               -3             0
# 17895  2019-09-29                2               -3           2.5
# 17896  2019-09-30                3               -4           9.5
#
# [17897 rows x 4 columns]

# %%
# remove unwanted entries from dataframe
unwanted_values = {'New Snow (cm)': ['--','.'],'Air Temp Max (C)': ['.', '--'],'Air Temp Min (C)': ['.', '--']}

for column, values in unwanted_values.items():
    cssl_data = cssl_data[~cssl_data[column].isin(values)]
cssl_data = cssl_data.dropna()
cssl_data = cssl_data.replace('T',0)

# convert data types
cssl_data['Date'] = pd.to_datetime(cssl_data['Date'])
numeric_columns = ['Air Temp Max (C)', 'Air Temp Min (C)', 'New Snow (cm)']
cssl_data[numeric_columns] = cssl_data[numeric_columns].astype(float)

# summary of cssl_data_no_0
print_data_summary(cssl_data,['Air Temp Max (C)', 'Air Temp Min (C)', 'New Snow (cm)'])
# Out:
# Dataset Summary:
# Shape: (17554, 4)
#
# Missing Values:
# Date                0
# Air Temp Max (C)    0
# Air Temp Min (C)    0
# New Snow (cm)       0
# dtype: int64
#
# Data Types:
# Date                datetime64[ns]
# Air Temp Max (C)           float64
# Air Temp Min (C)           float64
# New Snow (cm)              float64
# dtype: object
#
# Descriptive Statistics:
#        Air Temp Max (C)  Air Temp Min (C)  New Snow (cm)
# count      17554.000000      17554.000000   17554.000000
# mean          12.774714         -0.828637       2.733176
# std            9.418800          6.316899       9.225383
# min          -12.210000        -25.530000       0.000000
# 25%            4.995000         -5.000000       0.000000
# 50%           12.210000         -1.000000       0.000000
# 75%           21.000000          4.000000       0.000000
# max           37.000000         87.000000     132.080000

# %%
# calculate the average snowfall for each month to determine which months to exclude 
monthly_total_snowfall = cssl_data.groupby([cssl_data['Date'].dt.year, cssl_data['Date'].dt.month])['New Snow (cm)'].sum()
average_monthly_snowfall = monthly_total_snowfall.groupby(level=1).mean()
average_monthly_snowfall
# Out:
# Date
# 1     182.578571
# 2     196.574898
# 3     184.853673
# 4      89.163061
# 5      25.525673
# 6       4.124082
# 7       0.000000
# 8       0.000000
# 9       3.738776
# 10     24.962245
# 11     97.676771
# 12    171.941980
# Name: New Snow (cm), dtype: float64

# %%
# exclude June, July, August, and September due to their low snowfall 
cssl_data = cssl_data[~cssl_data['Date'].dt.month.isin([6,7,8,9])]
print_data_summary(cssl_data,['Air Temp Max (C)', 'Air Temp Min (C)', 'New Snow (cm)'])
# Out:
# Dataset Summary:
# Shape: (11618, 4)
#
# Missing Values:
# Date                0
# Air Temp Max (C)    0
# Air Temp Min (C)    0
# New Snow (cm)       0
# dtype: int64
#
# Data Types:
# Date                datetime64[ns]
# Air Temp Max (C)           float64
# Air Temp Min (C)           float64
# New Snow (cm)              float64
# dtype: object
#
# Descriptive Statistics:
#        Air Temp Max (C)  Air Temp Min (C)  New Snow (cm)
# count      11618.000000      11618.000000   11618.000000
# mean           7.890921         -4.070447       4.096479
# std            6.996173          4.732780      11.076267
# min          -12.210000        -25.530000       0.000000
# 25%            2.220000         -7.000000       0.000000
# 50%            7.770000         -3.330000       0.000000
# 75%           13.000000         -1.000000       1.000000
# max           29.000000         12.000000     132.080000

# %% [markdown]
# ## Blue Canyon - Nyack Airport Daily Relative Humidity

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION 
# read in the data 
humidity_data = pd.read_csv('Blue Canyon - Nyack Airport Daily Relative Humidity.csv')

#select relevant columns 
humidity_columns = ['datetime','humidity']
humidity_data = humidity_data[humidity_columns]

#take a look at dataframe 
humidity_data
# Out:
#          datetime  humidity
# 0      1970-10-01      14.1
# 1      1970-10-02      13.5
# 2      1970-10-03      15.3
# 3      1970-10-04      25.8
# 4      1970-10-05      26.4
# ...           ...       ...
# 17892  2019-09-26      44.5
# 17893  2019-09-27      69.2
# 17894  2019-09-28      85.5
# 17895  2019-09-29      83.4
# 17896  2019-09-30      86.0
#
# [17897 rows x 2 columns]

# %%
# drop null values 
humidity_data = humidity_data.dropna()

# change column names 
humidity_data = humidity_data.rename({'datetime':'Date','humidity':'Relative Humidity (%)'},axis='columns')

# convert 'Date' column to datetime datatype 
humidity_data['Date'] = pd.to_datetime(humidity_data['Date'])

#merge humidity_data and cssl_data
cssl_data_humidity = pd.merge(cssl_data, humidity_data, on='Date', how='inner')

# summary of merged dataset 
print_data_summary(cssl_data_humidity,['Air Temp Max (C)', 'Air Temp Min (C)', 'New Snow (cm)'])
# Out:
# Dataset Summary:
# Shape: (11444, 5)
#
# Missing Values:
# Date                     0
# Air Temp Max (C)         0
# Air Temp Min (C)         0
# New Snow (cm)            0
# Relative Humidity (%)    0
# dtype: int64
#
# Data Types:
# Date                     datetime64[ns]
# Air Temp Max (C)                float64
# Air Temp Min (C)                float64
# New Snow (cm)                   float64
# Relative Humidity (%)           float64
# dtype: object
#
# Descriptive Statistics:
#        Air Temp Max (C)  Air Temp Min (C)  New Snow (cm)
# count      11444.000000      11444.000000   11444.000000
# mean           7.893623         -4.080463       4.069643
# std            7.002468          4.737617      11.038661
# min          -12.210000        -25.530000       0.000000
# 25%            2.220000         -7.000000       0.000000
# 50%            7.770000         -3.330000       0.000000
# 75%           13.000000         -1.000000       1.000000
# ...

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis
#
# Carry out whatever EDA you need to for your project.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.

# %% [markdown]
# ### Univariate Distribution of Variables
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

columns_to_plot = [
    'Air Temp Max (C)', 
    'Air Temp Min (C)', 
    'Relative Humidity (%)', 
    'New Snow (cm)',]

for column in columns_to_plot:
    plt.figure(figsize=(8, 5))
    sns.histplot(cssl_data_humidity[column],bins=30)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ### Bivariate Relationships Between Features and New Snow (cm)

# %%
# Define pairs of columns for scatterplots
scatterplot_pairs = [
    ('Air Temp Max (C)', 'New Snow (cm)'),
    ('Air Temp Min (C)', 'New Snow (cm)'),
    ('Relative Humidity (%)', 'New Snow (cm)'),
]

# Create scatterplots in a loop
for x_col, y_col in scatterplot_pairs:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=x_col, y=y_col, data=cssl_data_humidity)
    plt.title(f'Scatterplot: {y_col} vs {x_col}')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# Check for correlation between variables 
correlation_matrix = cssl_data_humidity.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Transform New Snow (cm)

# %%
cssl_data_humidity['New Snow (cm)_log10'] = np.log10(cssl_data_humidity['New Snow (cm)']+1)
cssl_data_humidity['New Snow (cm)_sqrt'] = np.sqrt(cssl_data_humidity['New Snow (cm)'])

# %% [markdown]
# ### Distributions of Transformed New Snow (cm)

# %%
columns_to_plot_2 = [
    'New Snow (cm)_log10', 
    'New Snow (cm)_sqrt']

for column in columns_to_plot_2:
    plt.figure(figsize=(8, 5))
    sns.histplot(cssl_data_humidity[column],bins=30)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# ### Bivariate Relationships with New Snow (cm)_log10 and New Snow (cm)_sqrt

# %%
# Define pairs of columns for scatterplots
scatterplot_pairs_2 = [
    ('Air Temp Max (C)', 'New Snow (cm)_log10'),
    ('Air Temp Min (C)', 'New Snow (cm)_log10'),
    ('Relative Humidity (%)', 'New Snow (cm)_log10'),
    ('Air Temp Max (C)', 'New Snow (cm)_sqrt'),
    ('Air Temp Min (C)', 'New Snow (cm)_sqrt'),
    ('Relative Humidity (%)', 'New Snow (cm)_sqrt')
]

# Create scatterplots in a loop
for x_col, y_col in scatterplot_pairs_2:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=x_col, y=y_col, data=cssl_data_humidity)
    plt.title(f'Scatterplot: {y_col} vs {x_col}')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# Check for correlation between variables 
correlation_matrix = cssl_data_humidity.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Check for Multicollinearity

# %%
# Plot scatterplot between Relative Humidity (%) and Air Temp Max (C) + Air Temp Min (C)
scatterplot_pairs_3 = [
    ('Air Temp Max (C)', 'Relative Humidity (%)'),
    ('Air Temp Min (C)', 'Relative Humidity (%)')
]

# Create scatterplots in a loop
for x_col, y_col in scatterplot_pairs_3:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(x=x_col, y=y_col, data=cssl_data_humidity)
    plt.title(f'Scatterplot: {y_col} vs {x_col}')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.show()

# %% [markdown]
# ### Section 2 of EDA if you need it  - please give it a better title than this
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# **Potential Biases with Data Collection:**
#
# Historical weather data may be biased due to changes in measurement techniques, station locations, and data quality control standards. Over time with the development of technology and techniques the accuracy of data collection is improved, but inconsistent with the data collection of the past. While this is a potential problem, the variance in the data collection will not be great enough to disrupt our studies and analysis. Also, it could be possible that there could be a bias based on the area that the data comes from because different regions have varying climates and weather patterns, which can influence snowfall data.
#
# **Solution to Potential Biases:**
#
# We will address this problem by focusing on a specific region. Climate change may influence snowfall patterns, and historical data may not fully capture future trends. We'll make sure to thoroughly clean and validate the data to remove errors and inconsistencies. If necessary, we'll use techniques like data augmentation to increase the diversity of the dataset and reduce bias.
#
# **Potential Privacy Implications:**
#
# While weather data is generally not considered personally identifiable information, it's important to be aware of any potential privacy implications, especially if using real-time data sources. If using personal data, we'll anonymize and aggregate it to protect individual privacy. However, it is unlikely that we will use any personal data because our topic is mostly based on weather which doesn't involve any human subjects so we will mostly use publicly available data regarding temperature, humidity and snowfall amount that is the total depth of snow on the ground. We'll ensure that any models or predictions are accessible to all, regardless of socioeconomic status or location. We'll consider the potential impact of inaccurate predictions on vulnerable populations, such as those living in areas prone to severe winter weather. We'll also incorporate climate models and future projections into the analysis to account for potential shifts in snowfall patterns. We will clearly document the model development process and share the model's limitations, and regularly test the model for bias and take steps to mitigate it.

# %% [markdown]
# # Team Expectations

# %% [markdown]
# * *Be responsive and communicative during meetings and in text messages*
# * *Make sure to participate in meetings and throughout the project. For the final project everyone will have assigned tasks to complete to ensure everyone is contributing.*
# * *Let group know what you are working on and when completing a component of the project.*
# * *If you are having trouble completing a task, let the group know in a meeting or through text, so that others can help out*
# * *Every member should be communicatative and present throughout meetings and in discussing the project.*
# * *Make sure to prepare for meetings appropriately and do what is expected to allow for meetings to move along with ease.*
# * *Once a each portion of work is completed, double check with the rest of the group to make sure everyone agrees.*

# %% [markdown]
# # Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 10/23  |  4 PM | Read & Think about COGS 108 expectations; brainstorm topics/questions  | Determine best form of communication; Discuss and decide on final project topic; discuss hypothesis; begin background research |
# | 10/29  |  4 PM |  Do background research on topic | Discuss ideal dataset(s) and ethics; draft project proposal |
# | 10/30  | 4 PM  | Edit, finalize, and submit proposal; Search for datasets  | Discuss Wrangling and possible analytical approaches; Assign group members to lead each specific part   |
# | 11/5  | 4 PM  | Import & Wrangle Data; EDA | Review/Edit wrangling/EDA; Discuss Analysis Plan   |
# | 11/12  | 4 PM  | Finalize wrangling/EDA | Begin EDA/Analysis; Complete project check-in |
# | 11/26  | 4 PM  | Discuss/edit EDA/Analysis | Discuss/edit EDA/Analysis |
# | 11/27  | 4 PM  | Discuss/edit EDA/Analysis | Complete EDA/Analysis; Complete project check-in |
# | 12/3   | 4 PM  | Draft results/conclusion/discussion | Draft results/conclusion/discussion; Discuss/edit full project |
# | 12/10  | 4 PM  | Draft results/conclusion/discussion; Complete and finalize final project | Discuss/edit full project; Collectively finalize project; Complete project video |
# | 12/11  | Before 11:59 PM  | NA | Turn in Final Project & Group Project Surveys |
